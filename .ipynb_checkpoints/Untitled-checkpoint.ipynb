# %%
# %matplotlib inline
import pandas as pd

train = pd.read_csv('train.csv')
train.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1201  1202          60       RL         80.0    10400   Pave   NaN      Reg
# 712    713         120       RL         40.0     4671   Pave   NaN      IR1
# 102    103          90       RL         64.0     7018   Pave   NaN      Reg
# 1188  1189          60       RL         68.0     8935   Pave   NaN      IR1
# 288    289          20       RL          NaN     9819   Pave   NaN      IR1
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1201         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 712          HLS    AllPub    ...            0    NaN    NaN         NaN
# 102          Bnk    AllPub    ...            0    NaN    NaN         NaN
# 1188         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 288          Lvl    AllPub    ...            0    NaN  MnPrv         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# checking for missing values
train.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %% [markdown]
# ## Building class

# %%
number_of_rows = train.shape[0]

# distribution
(train[['Id','MSSubClass']].groupby('MSSubClass').count()/number_of_rows).sort_values(by='Id',ascending=0).plot(kind='bar')
(train[['Id','MSSubClass']].groupby('MSSubClass').count()/number_of_rows).plot(kind='bar')

# %%
def boxplot_sorted(df, by, column, rot=0):
    df2 = pd.DataFrame({col:vals[column] for col, vals in df.groupby(by)})
    meds = df2.median().sort_values()
    return df2[meds.index].boxplot(rot=rot, return_type="axes")

boxplot_sorted(train, 'MSSubClass', 'SalePrice')
train.boxplot(column='SalePrice', by='MSSubClass')

# %% [markdown]
# This feature must be transformed one way or another. To avoid one-hot encoding, we may have to assume an order on the classes (based on mean of SalePrice?). This could induce the linear relationship showed above.
#
# It may also make sense to group "similar" classes, although of course deciding how to group them may be an issue.
#
# That said, that seems to be a Paretto when looking at class distribution. Classes 20 and 60 amount to more than 55% of data.

# %% [markdown]
# # TODO
# - compare test set with train set, feature by feature. same distributions?
# - clean data for training
